# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv("total_merge.csv")
# Out:
# C:\Users\pierr\AppData\Local\Temp\ipykernel_6468\1371217147.py:7: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("total_merge.csv")

# %%
df.head()
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 3  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 4  tt0000147     movie  The Corbett-Fitzsimmons Fight
#
#                    originalTitle  isAdult  startYear  runtimeMinutes  \
# 0  The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
# 1  The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
# 2  The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
# 3  The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
# 4  The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
#
#                  genres_x  directors writers  ... release_date revenue  \
# 0  Documentary,News,Sport  nm0714557     NaN  ...   1897-01-01     0.0
# 1  Documentary,News,Sport  nm0714557     NaN  ...   1897-01-01     0.0
# ...

# %%
df.columns
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'runtimeMinutes', 'genres_x', 'directors', 'writers',
#        'titleId', 'title_x', 'isOriginalTitle', 'ordering', 'nconst',
#        'category', 'job', 'characters', 'averageRating', 'numVotes',
#        'primaryName', 'primaryProfession', 'knownForTitles', 'backdrop_path',
#        'budget', 'genres_y', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_countries', 'release_date', 'revenue', 'runtime', 'status',
#        'tagline', 'title_y', 'vote_average', 'vote_count',
#        'production_companies_name', 'production_companies_country'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# tconst                                0
# titleType                             0
# primaryTitle                         32
# originalTitle                        32
# isAdult                               0
# startYear                        565683
# runtimeMinutes                        0
# genres_x                         573986
# directors                        308500
# writers                         1184677
# titleId                           16780
# title_x                           16812
# isOriginalTitle                   16780
# ordering                          25186
# nconst                            25186
# category                          25186
# job                             6838618
# characters                      5057463
# averageRating                   3229065
# numVotes                        3229065
# primaryName                       25534
# primaryProfession                194188
# knownForTitles                    41378
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8431122 entries, 0 to 8431121
# Data columns (total 44 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   tconst                        object
#  1   titleType                     object
#  2   primaryTitle                  object
#  3   originalTitle                 object
#  4   isAdult                       float64
#  5   startYear                     float64
#  6   runtimeMinutes                float64
#  7   genres_x                      object
#  8   directors                     object
#  9   writers                       object
#  10  titleId                       object
#  11  title_x                       object
#  12  isOriginalTitle               float64
#  13  ordering                      float64
#  14  nconst                        object
#  15  category                      object
#  16  job                           object
# ...

# %%
df.sample()
# Out:
#              tconst titleType          primaryTitle         originalTitle  \
# 3437056  tt11282110     video  Lady Dee: Sex Addict  Lady Dee: Sex Addict
#
#          isAdult  startYear  runtimeMinutes       genres_x  directors writers  \
# 3437056      1.0     2019.0           125.0  Adult,Romance  nm7725038     NaN
#
#          ... release_date revenue  runtime  status tagline title_y  \
# 3437056  ...          NaN     NaN      NaN     NaN     NaN     NaN
#
#         vote_average vote_count  production_companies_name  \
# 3437056          NaN        NaN                        NaN
#
#          production_companies_country
# 3437056                           NaN
#
# [1 rows x 44 columns]

# %%
df.dtypes
# Out:
# tconst                           object
# titleType                        object
# primaryTitle                     object
# originalTitle                    object
# isAdult                         float64
# startYear                       float64
# runtimeMinutes                  float64
# genres_x                         object
# directors                        object
# writers                          object
# titleId                          object
# title_x                          object
# isOriginalTitle                 float64
# ordering                        float64
# nconst                           object
# category                         object
# job                              object
# characters                       object
# averageRating                   float64
# numVotes                        float64
# primaryName                      object
# primaryProfession                object
# knownForTitles                   object
# ...

# %%
df.drop_duplicates(subset ="tconst", keep = 'first', inplace=True)
df.head()
# Out:
#        tconst titleType                   primaryTitle  \
# 0   tt0000147     movie  The Corbett-Fitzsimmons Fight
# 8   tt0000502     movie                       Bohemios
# 15  tt0000574     movie    The Story of the Kelly Gang
# 35  tt0000591     movie               The Prodigal Son
# 41  tt0000615     movie             Robbery Under Arms
#
#                     originalTitle  isAdult  startYear  runtimeMinutes  \
# 0   The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
# 8                        Bohemios      0.0     1905.0           100.0
# 15    The Story of the Kelly Gang      0.0     1906.0            70.0
# 35              L'enfant prodigue      0.0     1907.0            90.0
# 41             Robbery Under Arms      0.0     1907.0            90.0
#
#                       genres_x  directors                        writers  ...  \
# 0       Documentary,News,Sport  nm0714557                            NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 757361 entries, 0 to 8431108
# Data columns (total 44 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   tconst                        757361 non-null  object
#  1   titleType                     757361 non-null  object
#  2   primaryTitle                  757358 non-null  object
#  3   originalTitle                 757358 non-null  object
#  4   isAdult                       757361 non-null  float64
#  5   startYear                     652604 non-null  float64
#  6   runtimeMinutes                757361 non-null  float64
#  7   genres_x                      677476 non-null  object
#  8   directors                     654488 non-null  object
#  9   writers                       546893 non-null  object
#  10  titleId                       755387 non-null  object
#  11  title_x                       755384 non-null  object
# ...

# %%
print(df.isnull().sum())
# Out:
# tconst                               0
# titleType                            0
# primaryTitle                         3
# originalTitle                        3
# isAdult                              0
# startYear                       104757
# runtimeMinutes                       0
# genres_x                         79885
# directors                       102873
# writers                         210468
# titleId                           1974
# title_x                           1977
# isOriginalTitle                   1974
# ordering                         25186
# nconst                           25186
# category                         25186
# job                             730084
# characters                      304657
# averageRating                   429124
# numVotes                        429124
# primaryName                      25222
# primaryProfession                50922
# knownForTitles                   27407
# backdrop_path                   641702
# ...

# %%
df['id'] = df['nconst'].combine_first(df['tconst'])
df.head()
# Out:
#        tconst titleType                   primaryTitle  \
# 0   tt0000147     movie  The Corbett-Fitzsimmons Fight
# 8   tt0000502     movie                       Bohemios
# 15  tt0000574     movie    The Story of the Kelly Gang
# 35  tt0000591     movie               The Prodigal Son
# 41  tt0000615     movie             Robbery Under Arms
#
#                     originalTitle  isAdult  startYear  runtimeMinutes  \
# 0   The Corbett-Fitzsimmons Fight      0.0     1897.0           100.0
# 8                        Bohemios      0.0     1905.0           100.0
# 15    The Story of the Kelly Gang      0.0     1906.0            70.0
# 35              L'enfant prodigue      0.0     1907.0            90.0
# 41             Robbery Under Arms      0.0     1907.0            90.0
#
#                       genres_x  directors                        writers  ...  \
# 0       Documentary,News,Sport  nm0714557                            NaN  ...
# ...

# %%
df.drop(columns=['tconst', 'nconst'], inplace=True)

print(df)
# Out:
#         titleType                                       primaryTitle  \
# 0           movie                      The Corbett-Fitzsimmons Fight
# 8           movie                                           Bohemios
# 15          movie                        The Story of the Kelly Gang
# 35          movie                                   The Prodigal Son
# 41          movie                                 Robbery Under Arms
# ...           ...                                                ...
# 8431056     movie                                Kuambil Lagi Hatiku
# 8431075     movie                                  The Copeland Case
# 8431076     movie  De la ilusión al desconcierto: cine colombiano...
# 8431093     movie                                    Dankyavar Danka
# 8431108     movie                                             6 Gunn
#
#                                              originalTitle  isAdult  \
# 0                            The Corbett-Fitzsimmons Fight      0.0
# ...

# %%
df['id_imdb'] = df['titleId'].combine_first(df['imdb_id'])
df.drop(columns=['titleId', 'imdb_id'], inplace=True)

# %%
df.drop(columns=['title_y'], inplace= True)

# %%
df.drop(columns=['job'], inplace= True)

# %%
df.drop(columns=['original_title'], inplace= True)

# %%
df.drop(columns=['title_x'], inplace= True)

# %%
df.drop(columns=['isOriginalTitle', 'ordering'], inplace=True)

# %%
df.drop(columns=['runtime'], inplace= True)

# %%
display(df.head())
# Out:
#    titleType                   primaryTitle                  originalTitle  \
# 0      movie  The Corbett-Fitzsimmons Fight  The Corbett-Fitzsimmons Fight
# 8      movie                       Bohemios                       Bohemios
# 15     movie    The Story of the Kelly Gang    The Story of the Kelly Gang
# 35     movie               The Prodigal Son              L'enfant prodigue
# 41     movie             Robbery Under Arms             Robbery Under Arms
#
#     isAdult  startYear  runtimeMinutes                    genres_x  directors  \
# 0       0.0     1897.0           100.0      Documentary,News,Sport  nm0714557
# 8       0.0     1905.0           100.0                         NaN  nm0063413
# 15      0.0     1906.0            70.0  Action,Adventure,Biography  nm0846879
# 35      0.0     1907.0            90.0                       Drama  nm0141150
# 41      0.0     1907.0            90.0                       Drama  nm0533958
#
# ...

# %%
print(df.isnull().sum())
# Out:
# titleType                            0
# primaryTitle                         3
# originalTitle                        3
# isAdult                              0
# startYear                       104757
# runtimeMinutes                       0
# genres_x                         79885
# directors                       102873
# writers                         210468
# category                         25186
# characters                      304657
# averageRating                   429124
# numVotes                        429124
# primaryName                      25222
# primaryProfession                50922
# knownForTitles                   27407
# backdrop_path                   641702
# budget                          552087
# genres_y                        552087
# homepage                        727874
# original_language               552087
# overview                        567982
# popularity                      552087
# poster_path                     572367
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 757361 entries, 0 to 8431108
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   titleType                     757361 non-null  object
#  1   primaryTitle                  757358 non-null  object
#  2   originalTitle                 757358 non-null  object
#  3   isAdult                       757361 non-null  float64
#  4   startYear                     652604 non-null  float64
#  5   runtimeMinutes                757361 non-null  float64
#  6   genres_x                      677476 non-null  object
#  7   directors                     654488 non-null  object
#  8   writers                       546893 non-null  object
#  9   category                      732175 non-null  object
#  10  characters                    452704 non-null  object
#  11  averageRating                 328237 non-null  float64
# ...

# %%
df.value_counts()
# Out:
# titleType  primaryTitle                          originalTitle                         isAdult  startYear  runtimeMinutes  genres_x                    directors                      writers                                  category  characters          averageRating  numVotes  primaryName           primaryProfession                       knownForTitles                               backdrop_path                     budget    genres_y                                                            homepage                                                     original_language  overview                                                                                                                                                                                                                                                                                                                                                                                     popularity  poster_path                 
# ...

# %%
df['status'].nunique()
# Out:
# 6

# %%
df_total = df

# %%
df.to_csv('premier_clean.csv', index=False)
